# %%
from codes.new_workbook import database as db
import pandas as pd

# %% [markdown]
# # Creating the excel workbook

# %%
excelfile = db('campaign01')

# %%
excelfile.createworkbook()

# %%
property_list = ['den','sus','cond','xrf']
excelfile.add_sheets(property_list)

# %%
excelfile.copy_col_for_all_sheets(property_list)

# %% [markdown]
# # Adding to excel workbook

# %%
for prop in property_list:
    excelfile.add_data(prop)
# Out:
# C:\tools\Manim\Lib\site-packages\numpy\core\fromnumeric.py:784: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# C:\tools\Manim\Lib\site-packages\numpy\core\fromnumeric.py:784: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# C:\tools\Manim\Lib\site-packages\numpy\core\fromnumeric.py:784: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# C:\tools\Manim\Lib\site-packages\numpy\core\fromnumeric.py:784: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# C:\tools\Manim\Lib\site-packages\numpy\core\fromnumeric.py:784: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# ...

# %%
df_final,df_cal= excelfile.select_and_process("ip_res")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\gabri\OneDrive\Área de Trabalho\Database_code\database_creation.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gabri/OneDrive/%C3%81rea%20de%20Trabalho/Database_code/database_creation.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> df_final,df_cal= excelfile.select_and_process("ip_res")
#
# File c:\Users\gabri\OneDrive\Área de Trabalho\Database_code\codes\new_workbook.py:53, in database.select_and_process(self, property)
#      51     return self.density()
#      52 elif property == 'ip_res':
# ---> 53     return self.ip_res()
#      54 elif property == 'v_p':
#      55     return self.vel('v_p')
#
# File c:\Users\gabri\OneDrive\Área de Trabalho\Database_code\codes\data_processing.py:189, in dataprocess.ip_res(self)
#     187 result_df.rename(columns={'Record_Id': 'sample id'}, inplace=True)
# ...

# %%
df_cal
# Out:
#    sample id        mean       std      median         max        min
# 0    cal_001   99.142073  3.210706  100.452400  101.033096  81.051598
# 11   cal_002   94.562481  0.880325   94.782249   95.653099  89.837196
# 22   cal_003   96.305574  1.187147   96.297096   97.455101  85.220703
# 33   cal_004   98.999874  3.159804   99.649445  100.687798  74.225800
# 49   cal_005  100.441215  1.065401  100.577347  101.363800  91.329399
# 55   cal_006   98.819564  0.170920   98.896103   98.975899  98.052399

# %%
excelfile.create_calibration_graphs('sus')
# Out:
# C:\tools\Manim\Lib\site-packages\numpy\core\fromnumeric.py:784: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# C:\tools\Manim\Lib\site-packages\numpy\core\fromnumeric.py:784: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# C:\tools\Manim\Lib\site-packages\numpy\core\fromnumeric.py:784: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# C:\tools\Manim\Lib\site-packages\numpy\core\fromnumeric.py:784: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# C:\tools\Manim\Lib\site-packages\numpy\core\fromnumeric.py:784: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# ...
